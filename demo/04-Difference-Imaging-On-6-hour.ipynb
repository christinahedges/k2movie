# %%
import k2movie
# %load_ext autoreload
# %autoreload 2
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Initialise the movie object
mov = k2movie.movie(name = 'EPIC212535880',
                    campaign = 6,
                    cadence='sixhour',
                    data_dir = '/Volumes/cupertino/database/',
                    cmap='inferno',tol=50,vmin=0,vmax=400,scale='linear')

# %%
mov.produce()
#mov.cadence = mov.cadence-3
#mov.produce()
mov.populate()
#mov.ar-=np.atleast_3d(mov.ar[:,:,0])
# Out:
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0)
# /Users/ch/anaconda/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# /Users/ch/anaconda/lib/python3.6/site-packages/numpy/lib/function_base.py:4016: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
mov.axes()
mov.stabilize()
mov.movie()

# %%
mov.inspect()
# Out:
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0)
# Location and Target Name specified. Using Location
