# %%
import k2movie
# %load_ext autoreload
# %autoreload 2
import astropy.units as u
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Initialise the movie object
mov = k2movie.movie(name = '39289',
                    campaign = 6,
                    data_dir = '/Volumes/cupertino/database/',
                    cmap='inferno',tol=50,verbose=True)
print(mov.channel)
# Out:
# Initialised:
# 	Campaign: 6
# 	Channel: None
# 	Pixel Tolerance: 50
# None

# %%
mov.inspect()
print(mov.channel)
# Out:
# Finding 39289
# 	Querying MAST for 39289
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0)
# 	Found :220.105898 deg,-27.142937 deg
# Finding channels...
# 220.105898 deg -27.142937 deg
# Channel: [4]
# Finding location on focal plane
# Inspecting
# /Users/ch/K2/projects/k2movie/k2movie/k2movie.py:599: RuntimeWarning: invalid value encountered in log10
#   y=ar.ravel()
# [4]

# %%
mov.movsampling=10
mov.compute()

# %%
import io
import base64
from IPython.display import HTML

video = io.open('Sycorax.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
